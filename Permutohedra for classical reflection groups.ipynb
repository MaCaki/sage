# %%
AA3 = RootSystem(["A",3]).ambient_space().weyl_group()
V = RootSystem(["A",2]).ambient_space()
e = V.basis()
Lambda = V.fundamental_weights()

id = e[0] + 2*e[1] + 3*e[2]
S3 = [w.action(id) for w in AA3]

# %%
V.simple_roots()
# Out:
# Finite family {1: (1, -1, 0), 2: (0, 1, -1)}

# %%
V.plot(alcoves=True, alcove_labels=True)
# Out:
# Graphics object consisting of 25 graphics primitives

# %% [markdown]
# The is a type $D$ permutohedron

# %%
L = RootSystem(["D",3]).ambient_space()
rho = L.rho()
print(rho)
plot_options = L.plot_parse_options()
W = L.weyl_group()
g = W.cayley_graph(side="right")
positions = [plot_options.projection(w.action(rho)) for w in W]

plt = RootSystem(["D",3]).ambient_space().plot(alcoves=True)
perm_D3 = Polyhedron(vertices = positions) 
plt += perm_D3.plot()
plt
# Out:
# (2, 1, 0)
# Graphics3d Object

# %%
rho
# Out:
# (2, 1, 0)
