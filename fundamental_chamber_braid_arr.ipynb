# %%
octant = Cone([(1,0,0), (0,1,0), (0,0,1)])
octant.plot()
# Out:
# Graphics3d Object

# %%
Phi = RootSystem(['A',4]).root_poset(); Phi
# Out:
# Finite poset containing 10 elements

# %%
a = hyperplane_arrangements.braid(4);  a.plot()
# Out:
# Displaying the essentialization.
# Graphics3d Object
